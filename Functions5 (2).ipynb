# %%
#1 What is the difference between a function and a method in Python?
#ans the major defference is  a method is a function that is defined within a class and is associated with an object instance of a class $
#a function is a block of code designed to perform a specific task.

# %%
#2Explain the concept of function arguments and parameters in Python.
#ans.  These are the variables defined within the parentheses of a function definition (e.g., def my_function(parameter1, parameter2):)
#They act as placeholders for the values that will be used inside the function.Think of them as the names of the boxes where the function will store the input data.
#fucntion arugments is the values that are passed to the function when it's called (e.g., my_function(value1, value2))&
#provide the actual data that the function will work with.Think of them as the data that gets put into the boxes (parameters).

# %%
#3What are the different ways to define and call a function in Python?
#ans.the define function using the def keyword & follwod by funticon name, parenthenss or colon than using indentation.call a function for simply use its name followed by parentheses and optionally with arguments.

# %%
#4 What is the purpose of the `return` statement in a Python function?
#ans The return statement in a pthon function serves to terminate the function's execution and send a value back to the caller.

# %%
#5. What are iterators in Python and how do they differ from iterables?
#ans the differences between Iterable and Iterator in Python is Iterable is basically an object that any user can iterate over.
# Iterator is also an object that helps a user in iterating over another object (that is iterable).

# %%
##Q6 Explain the concept of generators in Python and how they are defined.
#ans A Python generator function allows you to declare a function that
# behaves like an iterator, providing a faster and easier way to create iterators.
# They can be used on an abstract container of data to turn it into an iterable object like lists, dictionaries and strings.

# %%
# Q 7What are the advantages of using generators over regular functions?
#ANS   The  advantage of using a generator does not return its results all at once. it yields its values one by one, each time it is called

# %%
#8. What is a lambda function in Python and when is it typically used?
#ans The  lambda function is a small anonymous function and  lambda function can take any number of arguments but can only have one expression.
#  and typically used when a small, temporary function is needed, especially as arguments to higher-order functions like map(), filter(), or sorted(). They're ideal for concise, one-time-use functions where a full function definition with def

# %%
#9. Explain the purpose and usage of the `map()` function in Python.
# ans.    map() function in Python applies a given function to each item in an iterable (like a list, tuple, or string) and returns an iterator that yields the transformed results

# %%
#10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#ans. the map() function iterates through all items in the given iterable and executes the function we passed as an argument on each of them.
#The reduce() Function  us reduce() works differently than map() and filter(). It does not return a new list based on the function and iterable we will be  passed. Instead, it returns a single value.
#The filter() Function Similar to map() filter() takes a function object and an iterable and creates a new list.As the name suggests, filter() forms a new list that contains only elements that satisfy a certain condition, i.e. the function we passed returns True.

# %%
#11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given

list:[47,11,42,13];
from functools import reduce

nums = [1, 2, 3, 4]
ans = reduce(lambda x, y: x + y, nums)
print(ans)
# Out:
# 10

# %% [markdown]
# # Practical Questions:

# %%
 #1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
#the list.
def return_list(*args):
  a =[]
  for i in args:
    if type(i) == list:
      a.append(i)
    return a

# %%
return_list(1,2,4,354,35.35,[23,4,3,53,3,2,33,5,2,3,53],(23,3,25,35,))
# Out:
# []

# %%
#2. Create a Python function that accepts a string and returns the reverse of that string

def reverse_string(input_string):
  return input_string[::-1]

# %%
#3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
#each number

def square_numbers(numbers):
    squared_list = [number**2 for number in numbers]
    return squared_list

# %%
#4. Write a Python function that checks if a given number is prime or not from 1 to 200.
def  is_prime(number):
    if number < 2:
        return False
    for i in range(2, int(number**0.5) + 1):
        if number % i == 0:
            return False
    return True

# %%
is_prime(1)
# Out:
# False

# %%
#5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
#terms.

class FibonacciIterator:
    def __init__(self, n):
        self.n = n
        self.a = 0
        self.b = 1
        self.count = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.count < self.n:
            result = self.a
            self.a, self.b = self.b, self.a + self.b
            self.count += 1
            return result
        else:
            raise StopIteration

# %%
# Q6 Write a generator function in Python that yields the powers of 2 up to a given exponent.

def powers_of_2(exponent):
    for i in range(exponent + 1):
        yield 2**i

# %%
powers_of_2(15)
# Out:
# <generator object powers_of_2 at 0x7ccf30588ba0>

# %%
#7. Implement a generator function that reads a file line by line and yields each line as a string.
def read_file_line_by_line(filepath):
    """
    Reads a file line by line and yields each line as a string.
    """
    try:
        with open(filepath, 'r') as file:
            for line in file:
                yield line.strip()  # Remove leading/trailing whitespace
    except FileNotFoundError:
        print(f"Error: File '{filepath}' not found.")
        yield None

# %%
read_file_line_by_line()

# %%
#8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.


data = [('apple', 5), ('banana', 2), ('cherry', 8), ('date', 1)]
sorted_data = sorted(data, key=lambda x: x[1])
sorted_data
# Out:
# [('date', 1), ('banana', 2), ('apple', 5), ('cherry', 8)]

# %%
#9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.
def celsius_to_fahrenheit(celsius):
  return (celsius * 9/5) + 32

celsius_temps = [0, 10, 20, 30, 40]
fahrenheit_temps = list(map(celsius_to_fahrenheit, celsius_temps))
fahrenheit_temps
# Out:
# [32.0, 50.0, 68.0, 86.0, 104.0]

# %%
#10. Create a Python program that uses `filter()` to remove all the vowels from a given string.
def remove_vowels(input_string):
    vowels = "aeiouAEIOU"
    return "".join(filter(lambda char: char not in vowels, input_string))

# %%
remove_vowels()

# %%
#11) Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:







#Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
#product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
#order is smaller than 100,00 €.

#Write a Python program using lambda and map.
